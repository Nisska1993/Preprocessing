# %% [markdown]
# # Encoding

# %% [markdown]
# Transformer les valeurs non numeriques en valeurs numeriques.
# L'encodage ordinal pernt d'encoder les variables ordinales (dont les valeurs forment une hiérarchie)
